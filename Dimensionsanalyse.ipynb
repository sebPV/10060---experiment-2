# %% [markdown]
# $$
# s=\dfrac{1}{2}a\cdot t^2 + v_0\cdot t + s_0
# $$

# %% [markdown]
# $$
# s=Aa\cdot t^2 + Bv_0\cdot t + Cs_0
# $$

# %% [markdown]
# $$
# s=f(t,v,a)
# $$

# %% [markdown]
# $$
# \tau=t
# $$

# %% [markdown]
# $$
# \lambda=v\cdot t
# $$

# %% [markdown]
# $$
# \dfrac{s}{\lambda}=f\left(\dfrac{t}{\tau},\dfrac{v}{\lambda\tau^{-1}},\dfrac{a}{\lambda\tau^{-2}}\right)
# $$

# %% [markdown]
# $$
# \dfrac{s}{v\cdot t}=f\left(\dfrac{t}{t},\dfrac{v}{vt\cdot t^{-1}},\dfrac{a}{vt\cdot t^{-2}}\right)
# $$

# %% [markdown]
# $$
# \dfrac{s}{v\cdot t}=f\left(1,1,\dfrac{a}{st^{-2}}\right)
# $$

# %% [markdown]
# $$
# \dfrac{s}{v\cdot t}=f\left(\dfrac{a}{st^{-2}}\right)
# $$
